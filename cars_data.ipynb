# %% [markdown]
# <a href="https://colab.research.google.com/github/stacykeago/A-football-analyst-in-Mchezopesa-to-predict-the-result-of-a-game-Polynomial-and-logistic-regression/blob/main/cars_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pd.read.csv
